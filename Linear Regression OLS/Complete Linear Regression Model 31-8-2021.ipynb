# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import pandas_profiling
import  numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df = df.drop(columns=['Unnamed: 0'],axis = 1)

# %%
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
pf = df.profile_report()

# %%
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
 df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
X = df[['TV']]

# %%
X
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y = df.sales

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
linear.fit(X,y)
# Out:
# LinearRegression()

# %%
linear.coef_
# Out:
# array([0.04753664])

# %%
linear.intercept_
# Out:
# 7.032593549127693

# %%
file = 'linear_reg.sav'
pickle.dump(linear,open(file,'wb'))

# %%
linear.predict([[45]])
# Out:
# array([9.17174237])

# %%
(0.047*45)+7.01
# Out:
# 9.125

# %%
l = [45,5,6,7,89,34,67,23,45,478,4562]

# %%
for i in l:
    linear.predict([[i]])
    print(linear.predict([[i]]))
# Out:
# [9.17174237]
# [7.27027675]
# [7.31781339]
# [7.36535003]
# [11.26335455]
# [8.64883932]
# [10.21754846]
# [8.12593628]
# [9.17174237]
# [29.75510768]
# [223.8947472]

# %%
linear.score(X,y)
# Out:
# 0.611875050850071

# %% [markdown]
# ## Mutilinear Regression

# %%
 df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# High Bias and Low Bias

# %%
df.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
X = df[['TV', 'radio', 'newspaper']]

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df.sales

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
lm = LinearRegression()

# %%
lm.fit(X,y)
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 2.9388893694594085

# %%
lm.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %% [markdown]
# y = 0.04*TV + 0.18*Radio - 0.001*Newspaper + 2.93

# %%
lm.score(X,y)
# Out:
# 0.8972106381789522

# %%
X = df[['TV','radio']]
y  = df.sales

# %%
lm = LinearRegression()

# %%
lm.fit(X,y)
# Out:
# LinearRegression()

# %%
lm.score(X,y)
# Out:
# 0.8971942610828956

# %% [markdown]
#  ## Statistical Analysis for Feature Selection

# %%
import statsmodels.formula.api as smf

# %%
lm = smf.ols(formula = 'sales ~ TV', data = df).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Thu, 02 Sep 2021   Prob (F-statistic):           1.47e-42
# Time:                        20:25:18   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
lm1 = smf.ols(formula = 'sales ~ TV + radio', data = df).fit()

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Thu, 02 Sep 2021   Prob (F-statistic):           4.83e-98
# Time:                        20:25:18   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# ...

# %%
lm2 = smf.ols(formula = 'sales ~ TV + radio + newspaper', data = df).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 02 Sep 2021   Prob (F-statistic):           1.58e-96
# Time:                        20:25:18   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %% [markdown]
# ## Admission Prediction Model

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge,LassoCV,RidgeCV, ElasticNet,ElasticNetCV,LinearRegression,Lasso
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %% [markdown]
# ## 1. Data preprocessing

# %%
df = pd.read_csv('Admission_Prediction.csv')

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3        NaN        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %%
df = df.drop(columns=['Serial No.'],axis = 1)

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337.0        118.0                4.0  4.5  4.5  9.65         1
# 1        324.0        107.0                4.0  4.0  4.5  8.87         1
# 2          NaN        104.0                3.0  3.0  3.5  8.00         1
# 3        322.0        110.0                3.0  3.5  2.5  8.67         1
# 4        314.0        103.0                2.0  2.0  3.0  8.21         0
# ..         ...          ...                ...  ...  ...   ...       ...
# 495      332.0        108.0                5.0  4.5  4.0  9.02         1
# 496      337.0        117.0                5.0  5.0  5.0  9.87         1
# 497      330.0        120.0                5.0  4.5  5.0  9.56         1
# 498      312.0        103.0                4.0  4.0  5.0  8.43         0
# 499      327.0        113.0                4.0  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# 2               0.72
# ...

# %% [markdown]
# ## 2. EDA

# %%
pf = df.profile_report()

# %%
pf.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## 3. Handeling Missing Value

# %%
df.isnull().sum()
# Out:
# GRE Score            15
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR  \
# count  485.000000   490.000000         485.000000  500.000000  500.00000
# mean   316.558763   107.187755           3.121649    3.374000    3.48400
# std     11.274704     6.112899           1.146160    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.00000
# mean     8.576440    0.560000          0.72174
# std      0.604813    0.496884          0.14114
# min      6.800000    0.000000          0.34000
# 25%      8.127500    0.000000          0.63000
# ...

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0      337.0        118.0                4.0  4.5  4.5  9.65         1
# 1      324.0        107.0                4.0  4.0  4.5  8.87         1
# 2        NaN        104.0                3.0  3.0  3.5  8.00         1
# 3      322.0        110.0                3.0  3.5  2.5  8.67         1
# 4      314.0        103.0                2.0  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
df['GRE Score'] = df['GRE Score'].fillna(df['GRE Score'].mean())

# %%
df.isnull().sum()
# Out:
# GRE Score             0
# TOEFL Score          10
# University Rating    15
# SOP                   0
# LOR                   0
# CGPA                  0
# Research              0
# Chance of Admit       0
# dtype: int64

# %%
df['TOEFL Score'] = df['TOEFL Score'].fillna(df['TOEFL Score'].mean())

# %%
df['University Rating'] = df['University Rating'].fillna(df['University Rating'].mean())

# %%
df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
pf1 = df.profile_report()
pf1.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## 4. Column Treatment

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
df.rename(columns={'GRE Score':'GRE_Score',
                  'TOEFL Score':'TOEFL_Score',
                  'University Rating':'University_Rating',
                  'SOP':'SOP','LOR':'LOR','CGPA':'CGPA',
                  'Research':'Research','Chance of Admit':'Chance_of_Admit'},inplace=True)

# %%
df.columns
# Out:
# Index(['GRE_Score', 'TOEFL_Score', 'University_Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance_of_Admit'],
#       dtype='object')

# %% [markdown]
# ## 5. Statistical Analysis

# %%
df
# Out:
#       GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research  \
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
#      Chance_of_Admit
# 0               0.92
# 1               0.76
# ...

# %%
lm = smf.ols(formula = 'Chance_of_Admit ~ GRE_Score',data=df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Chance_of_Admit   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.643
# Method:                 Least Squares   F-statistic:                     899.7
# Date:                Thu, 02 Sep 2021   Prob (F-statistic):          1.13e-113
# Time:                        20:25:59   Log-Likelihood:                 528.02
# No. Observations:                 500   AIC:                            -1052.
# Df Residuals:                     498   BIC:                            -1044.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.5065      0.108    -23.274      0.000      -2.718      -2.295
# ...

# %%
lm = smf.ols(formula = 'Chance_of_Admit ~ GRE_Score +TOEFL_Score + University_Rating + SOP + LOR + CGPA + Research',data=df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Chance_of_Admit   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     321.7
# Date:                Thu, 02 Sep 2021   Prob (F-statistic):          4.36e-179
# Time:                        20:25:59   Log-Likelihood:                 699.68
# No. Observations:                 500   AIC:                            -1383.
# Df Residuals:                     492   BIC:                            -1350.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
lm = smf.ols(formula = 'Chance_of_Admit ~ GRE_Score +TOEFL_Score + University_Rating  + LOR + CGPA + Research',data=df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Chance_of_Admit   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     375.8
# Date:                Thu, 02 Sep 2021   Prob (F-statistic):          2.43e-180
# Time:                        20:25:59   Log-Likelihood:                 699.56
# No. Observations:                 500   AIC:                            -1385.
# Df Residuals:                     493   BIC:                            -1356.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 6. Model Prepration

# %%
df
# Out:
#       GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research  \
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
#      Chance_of_Admit
# 0               0.92
# 1               0.76
# ...

# %%
X = df.drop(columns=['Chance_of_Admit'])

# %%
y = df.Chance_of_Admit

# %%
X
# Out:
#       GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance_of_Admit, Length: 500, dtype: float64

# %% [markdown]
# ## 7. Data Transformation

# %%
scaler = StandardScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[ 1.84274116e+00,  1.78854223e+00,  7.78905651e-01, ...,
#          1.09894429e+00,  1.77680627e+00,  8.86405260e-01],
#        [ 6.70814288e-01, -3.10581135e-02,  7.78905651e-01, ...,
#          1.09894429e+00,  4.85859428e-01,  8.86405260e-01],
#        [ 5.12433309e-15, -5.27312752e-01, -1.07876604e-01, ...,
#          1.73062093e-02, -9.54042814e-01,  8.86405260e-01],
#        ...,
#        [ 1.21170361e+00,  2.11937866e+00,  1.66568791e+00, ...,
#          1.63976333e+00,  1.62785086e+00,  8.86405260e-01],
#        [-4.10964364e-01, -6.92730965e-01,  7.78905651e-01, ...,
#          1.63976333e+00, -2.42366993e-01, -1.12815215e+00],
#        [ 9.41258951e-01,  9.61451165e-01,  7.78905651e-01, ...,
#          1.09894429e+00,  7.67219636e-01, -1.12815215e+00]])

# %%
x_scale = scaler.fit_transform(X)

# %%
df1 = pd.DataFrame(x_scale)

# %%
df1.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-02 14:57:33.162462&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df1.describe()
# Out:
#                   0             1             2             3             4  \
# count  5.000000e+02  5.000000e+02  5.000000e+02  5.000000e+02  5.000000e+02
# mean   4.350520e-15  9.419132e-16  5.608847e-16  2.926548e-16 -1.332268e-17
# std    1.001002e+00  1.001002e+00  1.001002e+00  1.001002e+00  1.001002e+00
# min   -2.394225e+00 -2.512331e+00 -1.881441e+00 -2.397950e+00 -2.686789e+00
# 25%   -6.814090e-01 -6.927310e-01 -9.946589e-01 -8.828175e-01 -5.235128e-01
# 50%    5.124333e-15 -3.105811e-02 -1.078766e-01  1.272712e-01  1.730621e-02
# 75%    6.708143e-01  7.960330e-01  7.789057e-01  6.323155e-01  5.581253e-01
# max    2.113186e+00  2.119379e+00  1.665688e+00  1.642404e+00  1.639763e+00
#
#                   5             6
# count  5.000000e+02  5.000000e+02
# mean   3.091971e-15 -2.202682e-16
# std    1.001002e+00  1.001002e+00
# min   -2.940115e+00 -1.128152e+00
# 25%   -7.430227e-01 -1.128152e+00
# 50%   -2.720919e-02  8.864053e-01
# 75%    7.672196e-01  8.864053e-01
# ...

# %% [markdown]
# ## 8. Check Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
 x_scale.shape
# Out:
# (500, 7)

# %%
vif_df = pd.DataFrame()

# %%
vif_df['vif'] = [variance_inflation_factor(x_scale,i) for i in range( x_scale.shape[1])]

# %%
vif_df['features'] = X.columns

# %%
vif_df
# Out:
#         vif           features
# 0  4.153268          GRE_Score
# 1  3.792866        TOEFL_Score
# 2  2.508768  University_Rating
# 3  2.775750                SOP
# 4  2.037308                LOR
# 5  4.651670               CGPA
# 6  1.459311           Research

# %% [markdown]
# ## 9. Training and Testing Data

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scale,y,test_size=0.25,random_state=35)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.8209061766026746

# %%
model.score(x_test,y_test)
# Out:
# 0.8158797068035137

# %% [markdown]
# ### Check Accuracy of Model

# %%
def adj_r2(x,y):
    r2 = model.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train,y_train)
# Out:
# 0.817490218118257

# %%
adj_r2(x_test,y_test)
# Out:
# 0.8048639627661172

# %% [markdown]
# ## 10. Model Dump

# %%
import pickle

# %%
pickle.dump(model,open('Admission_lr_model.pickle','wb'))

# %% [markdown]
# ## 11. Prediction

# %%
df
# Out:
#       GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research  \
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
#      Chance_of_Admit
# 0               0.92
# 1               0.76
# ...

# %%
model.predict([[337.00,118.0,4.0,4.5,4.5,9.65,1]])
# Out:
# array([9.13333947])

# %%
test1 = scaler.transform([[314,103,2,2,3,8.21,0]])
test1
# Out:
# array([[-0.23066792, -0.69273097, -0.99465886, -1.3878618 , -0.52351283,
#         -0.6064802 , -1.12815215]])

# %%
test2 = scaler.transform([[324.000000,107.0,4.0,4.0,4.5,8.87,1]])
test2
# Out:
# array([[ 0.67081429, -0.03105811,  0.77890565,  0.63231549,  1.09894429,
#          0.48585943,  0.88640526]])

# %%
model.predict([[1.84274116, 1.78854223, 0.77890565, 1.13735981, 1.09894429,
        1.77680627, 0.88640526]])
# Out:
# array([0.95272823])

# %%
model.predict([[ 0.67081429, -0.03105811,  0.77890565,  0.63231549,  1.09894429,
         0.48585943,  0.88640526]])
# Out:
# array([0.8058744])

# %%
model.predict([[-0.23066792, -0.69273097, -0.99465886, -1.3878618 , -0.52351283,
        -0.6064802 , -1.12815215]])
# Out:
# array([0.6226688])

# %% [markdown]
# ## Model Equation

# %%
model.intercept_
# Out:
# 0.7211671439089439

# %%
model.coef_
# Out:
# array([0.01674134, 0.01637765, 0.00402475, 0.00727881, 0.01630187,
#        0.07262678, 0.01471891])

# %% [markdown]
# # 12. Regularization Technique

# %% [markdown]
# ## 1. Lasso

# %%
lassocv =LassoCV(cv = 100,max_iter=2000000,normalize=True)

# %%
lassocv.fit(x_train,y_train)
# Out:
# LassoCV(cv=100, max_iter=2000000, normalize=True)

# %%
lassocv.alpha_
# Out:
# 6.417432411805146e-06

# %%
lasso = Lasso(alpha=lassocv.alpha_)

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=6.417432411805146e-06)

# %% [markdown]
# ### Accuracy Check

# %%
lasso.score(x_train,y_train)
# Out:
# 0.8209061731397759

# %%
lasso.score(x_test,y_test)
# Out:
# 0.8158866343679496

# %%
adj_r2(x_train,y_train)
# Out:
# 0.817490218118257

# %%
adj_r2(x_test,y_test)
# Out:
# 0.8048639627661172

# %% [markdown]
# ## Ridge

# %%
alphas = np.random.uniform(low=0,high=10,size=(50,))

# %%
ridgecv = RidgeCV(alphas=alphas,cv =10,normalize=True)

# %%
ridgecv.fit(x_train,y_train)
# Out:
# RidgeCV(alphas=array([8.01970237, 4.55751998, 7.99271069, 0.7891711 , 3.88861732,
#        4.37106149, 3.7952667 , 8.94441046, 7.52803817, 1.24775924,
#        8.83468742, 1.45216909, 9.89643785, 1.8927076 , 0.53090026,
#        7.84184575, 0.74148606, 5.45698159, 8.39975208, 0.77813256,
#        5.88627259, 7.71459557, 4.31287223, 5.38834358, 4.63054292,
#        5.13895521, 6.44181505, 0.01130803, 6.58052563, 8.33634626,
#        1.21263724, 3.4678931 , 6.85218547, 9.03417786, 3.80224613,
#        7.89438208, 6.50409434, 1.97214253, 0.41833661, 2.34665044,
#        6.0613026 , 8.59200263, 5.8771447 , 3.37539079, 4.98244277,
#        2.33461059, 9.14464147, 9.1679196 , 5.00620694, 0.11422177]),
#         cv=10, normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.011308030260614998

# %%
ridge_lr = Ridge(alpha = ridgecv.alpha_)
ridge_lr.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.011308030260614998)

# %%
ridge_lr.score(x_train,y_train)
# Out:
# 0.8209061758915801

# %%
ridge_lr.score(x_test,y_test)
# Out:
# 0.8158795197119567

# %% [markdown]
# ## Elastic Net

# %%
elastic_cv = ElasticNetCV(alphas=None,cv=10)
elastic_cv.fit(x_train,y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
elastic_cv.alpha_
# Out:
# 0.0002488973608093338

# %%
elastic_cv.l1_ratio_
# Out:
# 0.5

# %%
ElasticNet = ElasticNet(alpha=elastic_cv.alpha_,l1_ratio=elastic_cv.l1_ratio_)

# %%
ElasticNet.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.0002488973608093338)

# %%
ElasticNet.score(x_train,y_train)
# Out:
# 0.820904848293253

# %%
ElasticNet.score(x_test,y_test)
# Out:
# 0.8159987521157861
